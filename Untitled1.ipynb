# %%
import pandas as pd
df = pd.read_csv('Book1.csv')
print(df)
df.plot()
df.hist()
# Out:
#          Day  Temperature Weather Event
# 0     Monday           22   Sunny   Hot
# 1    Tuesday           12   Windy  Cold
# 2  Wednesday           10   Windy  Cold
# 3   Thursday           18   Sunny   Hot
# 4     Friday           19   Sunny   Hot
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020B5E9C4AC0>]],
#       dtype=object)

# %%
# %matplotlib tk
